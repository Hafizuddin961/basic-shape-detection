# %% [markdown]
# ## **In this code, we will review four bitwise operations: AND, OR, XOR, and NOT.**
#
# First we need to mount our code with google drive.

# %%
# To mount code with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Import all the package that we will use for the code.

# %%
# Import the necessary packages
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# First, let's draw a rectangle.

# %%
canvas = np.zeros((300, 300), dtype = "uint8")
# Task 1
# Create in filled rectangle using opencv and show the image :
start_point4 = (50, 200)
end_point4 = (200, 225)
colour4 = (120)
thickness2 = -1
rectangle = cv2.rectangle(canvas, start_point4, end_point4, colour4, thickness2)
cv2_imshow(rectangle)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F8F7658E828>

# %% [markdown]
# Secondly, let's draw a circle.

# %%
circle = np.zeros((300, 300), dtype = "uint8")
# Task 2
# Create in filled circle using opencv and show the image :
cv2_imshow(circle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e5198b8bd52> in <module>()
# ----> 1 circle = np.zeros((300, 300), dtype = "uint8")
#       2 # Task 2
#       3 # Create in filled circle using opencv and show the image :
#       4 cv2_imshow(circle)
#
# NameError: name 'np' is not defined

# %% [markdown]
# A bitwise 'AND' is only True when both rectangle and circle have a value that is 'ON'. Simply put, the bitwise_and function examines every pixel in rectangle and circle. If both pixels have a value greater than zero, that pixel is turned 'ON' (i.e set to 255 in the output image). If both pixels are not greater than zero, then the output pixel is left 'OFF' with a value of 0.

# %%
bitwiseAnd = cv2.bitwise_and(rectangle, circle)
cv2_imshow(bitwiseAnd)

# %% [markdown]
# A bitwise 'OR' examines every pixel in rectangle and circle. If either pixel in rectangle or circle is greater than zero, then the output pixel has a value of 255, otherwise it is 0.

# %%
# Task 3
# Apply opencv bitwise_or and show the image :

# %% [markdown]
# The bitwise 'XOR' is identical to the 'OR' function, with one exception: both rectangle and circle are not allowed to have values greater than 0.

# %%
# Task 4
# Apply opencv bitwise_xor and show the image :

# %% [markdown]
# Finally, the bitwise 'NOT' inverts the values of the pixels. Pixels with a value of 255 become 0, and pixels with a value of 0 become 255.

# %%
# Task 4
# Apply opencv bitwise_not and show the image :
